# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
books_df = pd.read_csv("books.csv",on_bad_lines='skip')

# %%
books_df.shape
# Out:
# (11123, 12)

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.0+ MB

# %%
books_df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %%
books_df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
books_df.describe(include="all")
# Out:
#               bookID      title       authors  average_rating        isbn  \
# count   11123.000000      11123         11123    11123.000000       11123
# unique           NaN      10348          6639             NaN       11123
# top              NaN  The Iliad  Stephen King             NaN  0439785960
# freq             NaN          9            40             NaN           1
# mean    21310.856963        NaN           NaN        3.934075         NaN
# std     13094.727252        NaN           NaN        0.350485         NaN
# min         1.000000        NaN           NaN        0.000000         NaN
# 25%     10277.500000        NaN           NaN        3.770000         NaN
# 50%     20287.000000        NaN           NaN        3.960000         NaN
# 75%     32104.500000        NaN           NaN        4.140000         NaN
# max     45641.000000        NaN           NaN        5.000000         NaN
#
#               isbn13 language_code     num_pages  ratings_count  \
# ...

# %%
books_df.rename(columns={'  num_pages':'num_page'}, inplace=True)

# %%
rating_count_mean = books_df["ratings_count"].mean()
rating_count_mean
# Out:
# 17942.848062573048

# %%
avg_rating_mean = books_df["average_rating"].mean()
avg_rating_mean
# Out:
# 3.934075339386829

# %%
# high rated books
books_df.sort_values(by=['average_rating'],ascending=False)
# Out:
#        bookID                                              title  \
# 624      2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 9893    39829  His Princess Devotional: A Royal Encounter Wit...
# 4788    17224  The Diamond Color Meditation: Color Pathway to...
# 9324    36853                 Tyrannosaurus Wrecks (Stanley  #1)
# 9720    38804      The Irish Anatomist: A Study of Flann O'Brien
# ...       ...                                                ...
# 6877    25903  I'll Be Home Before Midnight and I Won't Get P...
# 3492    12712  Brodie's notes on Aldous Huxley's brave new world
# 2533     9338         Insights: Talks On The Nature Of Existence
# 2532     9337  How To Meditate: An Anthology Of Talks On Medi...
# 10497   42758  The Fantastic Vampire: Studies in the Children...
#
#                                                  authors  average_rating  \
# 624                  Aristophanes/F.W. Hall/W.M. Geldart             5.0
# ...

# %%
# popular books
books_df["w_rating"] = books_df["average_rating"]*books_df["ratings_count"]

# %%
books_df.sort_values(by=['w_rating'],ascending=False)
# Out:
#        bookID                                              title  \
# 10336   41865                            Twilight (Twilight  #1)
# 1697     5907                The Hobbit  or There and Back Again
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4415    15881  Harry Potter and the Chamber of Secrets (Harry...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# ...       ...                                                ...
# 264       797                              Lonely Planet Londres
# 265       799  Out to Eat London 2002 (Lonely Planet Out to Eat)
# 6999    26525                               Leadership Challenge
# 10862   44433                  Courageous Faith Through the Year
# 5779    21703             The Best American Mystery Stories 2002
#
#                                                  authors  average_rating  \
# 10336                                    Stephenie Meyer            3.59
# ...

# %%
books_df[books_df['w_rating']==max(books_df["w_rating"])]
# Out:
#        bookID                    title          authors  average_rating  \
# 10336   41865  Twilight (Twilight  #1)  Stephenie Meyer            3.59
#
#              isbn         isbn13 language_code  num_page  ratings_count  \
# 10336  0316015849  9780316015844           eng       501        4597666
#
#        text_reviews_count publication_date                  publisher  \
# 10336               94265         9/6/2006  Little  Brown and Company
#
#           w_rating
# 10336  16505620.94

# %%
avg_sort =books_df.sort_values(by=["average_rating"],ascending=False)
avg_sort
# Out:
#        bookID                                              title  \
# 624      2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 9893    39829  His Princess Devotional: A Royal Encounter Wit...
# 4788    17224  The Diamond Color Meditation: Color Pathway to...
# 9324    36853                 Tyrannosaurus Wrecks (Stanley  #1)
# 9720    38804      The Irish Anatomist: A Study of Flann O'Brien
# ...       ...                                                ...
# 6877    25903  I'll Be Home Before Midnight and I Won't Get P...
# 3492    12712  Brodie's notes on Aldous Huxley's brave new world
# 2533     9338         Insights: Talks On The Nature Of Existence
# 2532     9337  How To Meditate: An Anthology Of Talks On Medi...
# 10497   42758  The Fantastic Vampire: Studies in the Children...
#
#                                                  authors  average_rating  \
# 624                  Aristophanes/F.W. Hall/W.M. Geldart             5.0
# ...

# %%
plt.plot(avg_sort["average_rating"],avg_sort["num_page"])
plt.xlim(0,5)
plt.xlabel("Rating")
plt.ylabel("Number of Pages")
plt.ylim(0,4000)
plt.title("Number-of-pages / rating graph")
plt.show()

# %%
books_df.head(2)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
#
#   language_code  num_page  ratings_count  text_reviews_count publication_date  \
# 0           eng       652        2095690               27591        9/16/2006
# 1           eng       870        2153167               29221         9/1/2004
#
#          publisher    w_rating
# 0  Scholastic Inc.  9577303.30
# 1  Scholastic Inc.  9667719.83

# %%
for i in range(len(books_df["publication_date"])):
    books_df["publication_date"][i]=books_df["publication_date"][i][-4:]
# Out:
# C:\Users\RAHUL SUTHAR\AppData\Local\Temp\ipykernel_13188\4040627211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books_df["publication_date"][i]=books_df["publication_date"][i][-4:]

# %%
books_df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %%
new_df3 = books_df[books_df["publication_date"]=="1960"]

# %%
new_df3.shape
# Out:
# (6, 13)

# %%
new_df3
# Out:
#        bookID                                          title  \
# 963      3258                      Greek Tragedies  Volume 2
# 3354    12250                                   Greek Lyrics
# 3589    13018  Cliffsnotes on Shakespeare's Henry IV  Part 1
# 7240    27800                                Faust  Part Two
# 9809    39361  Paws Before Dying (A Dog Lover's Mystery  #4)
# 10459   42594     CliffsNotes on Shakespeare's Twelfth Night
#
#                                                  authors  average_rating  \
# 963    David Grene/Richmond Lattimore/Aeschylus/Sopho...            4.29
# 3354                                  Richmond Lattimore            3.98
# 3589     James K. Lowers/William Shakespeare/CliffsNotes            3.88
# 7240             Johann Wolfgang von Goethe/Philip Wayne            3.73
# 9809                                        Susan Conant            3.90
# 10459  James Lamar Roberts/CliffsNotes/William Shakes...            4.16
#
# ...

# %%
#most popular book of the 60s?
new_df3.sort_values(by=["w_rating"],ascending=False)
# Out:
#        bookID                                          title  \
# 9809    39361  Paws Before Dying (A Dog Lover's Mystery  #4)
# 963      3258                      Greek Tragedies  Volume 2
# 3354    12250                                   Greek Lyrics
# 7240    27800                                Faust  Part Two
# 3589    13018  Cliffsnotes on Shakespeare's Henry IV  Part 1
# 10459   42594     CliffsNotes on Shakespeare's Twelfth Night
#
#                                                  authors  average_rating  \
# 9809                                        Susan Conant            3.90
# 963    David Grene/Richmond Lattimore/Aeschylus/Sopho...            4.29
# 3354                                  Richmond Lattimore            3.98
# 7240             Johann Wolfgang von Goethe/Philip Wayne            3.73
# 3589     James K. Lowers/William Shakespeare/CliffsNotes            3.88
# 10459  James Lamar Roberts/CliffsNotes/William Shakes...            4.16
#
# ...

# %%
books_df.sort_values(by=["authors"])
# Out:
#        bookID                                              title  \
# 8037    30855                               A Woman in Jerusalem
# 7169    27503                                The Liberated Bride
# 4952    17883  Notes from Underground & A Confession (Everyma...
# 10110   40880  Jack Vance: Critical Appreciations and a Bibli...
# 7300    28116  The Know-It-All: One Man's Humble Quest to Bec...
# ...       ...                                                ...
# 7383    28419                                         La Débâcle
# 7379    28413                               The Ladies' Paradise
# 7377    28409                                    The Masterpiece
# 7375    28407                                           Germinal
# 1246     4314            Monsieur Ibrahim et les fleurs du Coran
#
#                                                  authors  average_rating  \
# 8037                         A.B. Yehoshua/Hillel Halkin            3.43
# ...

# %%
pd.DataFrame(books_df['authors'].unique())
# Out:
#                                                       0
# 0                            J.K. Rowling/Mary GrandPré
# 1                                          J.K. Rowling
# 2                                W. Frederick Zimmerman
# 3                                         Douglas Adams
# 4                             Douglas Adams/Stephen Fry
# ...                                                 ...
# 6634                                 Mario Vargas Llosa
# 6635  C.S. Lewis/Margarita E. Valdes/Gemma Gallart/P...
# 6636                       C.S. Lewis/Ana Falcão Bastos
# 6637        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos
# 6638  William T. Vollmann/Larry McCaffery/Michael He...
#
# [6639 rows x 1 columns]

# %%
df =books_df.groupby("authors",as_index=False)['num_page'].sum()

# %%
df =pd.DataFrame(df)
df
# Out:
#                                                 authors  num_page
# 0                           A.B. Yehoshua/Hillel Halkin       832
# 1          A.D.P. Briggs/Leo Tolstoy/Fyodor Dostoyevsky       256
# 2     A.E. Cunningham/Harlan Ellison/Charles F. Mill...       232
# 3                                           A.J. Jacobs       389
# 4                                            A.M. Homes       256
# ...                                                 ...       ...
# 6634                         Émile Zola/Henri Mitterand       462
# 6635         Émile Zola/Robert Lethbridge/Elinor Dorday       592
# 6636                Émile Zola/Robin Buss/Brian  Nelson       438
# 6637                           Émile Zola/Roger Pearson      1056
# 6638                              Éric-Emmanuel Schmitt        85
#
# [6639 rows x 2 columns]

# %%
# most page written by stephen king
df_sort =df.sort_values(by=['num_page'],ascending=False)
df_sort
# Out:
#                                                 authors  num_page
# 5786                                       Stephen King     18219
# 4711                                   Orson Scott Card     14066
# 2640                                     J.R.R. Tolkien     12537
# 1120                                        Dan Simmons     11700
# 4747                                     P.G. Wodehouse     11619
# ...                                                 ...       ...
# 1480          Douglas Preston/Lincoln Child/Scott Brick         0
# 4789                      Patricia Cornwell/Kate Burton         0
# 2233                    Gustave Flaubert/Donada  Peters         0
# 2808                James Redfield/Lou Diamond Phillips         0
# 1238  David Bromberg/Jay Ungar/Molly Mason/Garrison ...         0
#
# [6639 rows x 2 columns]

# %%
plt.figure(figsize=(10,4))
plt.bar(df_sort["authors"][:5],height=df_sort["num_page"][:5])
plt.xlabel("Authors")
plt.ylabel("Number of page")
plt.title("Top 5 authors who wrote most pages")
plt.show()

# %%
df2 =books_df.groupby("authors",as_index=False)["title"].count()

# %%
df2 =pd.DataFrame(df2)

# %%
df2.sort_values(by=['title'],ascending=False)
# Out:
#                                             authors  title
# 5786                                   Stephen King     40
# 4747                                 P.G. Wodehouse     40
# 5470                               Rumiko Takahashi     39
# 4711                               Orson Scott Card     35
# 46                                  Agatha Christie     33
# ...                                             ...    ...
# 3066                       Joanne Harris/Fran Warde      1
# 811                    Carolyn Keene/Mildred Benson      1
# 812   Carolyn Keene/Russell H. Tandy/Mildred Benson      1
# 3063                                  Joanna Weaver      1
# 6638                          Éric-Emmanuel Schmitt      1
#
# [6639 rows x 2 columns]

# %%
df3=pd.concat([df2,df["num_page"]],axis=1)
df3
# Out:
#                                                 authors  title  num_page
# 0                           A.B. Yehoshua/Hillel Halkin      2       832
# 1          A.D.P. Briggs/Leo Tolstoy/Fyodor Dostoyevsky      1       256
# 2     A.E. Cunningham/Harlan Ellison/Charles F. Mill...      1       232
# 3                                           A.J. Jacobs      1       389
# 4                                            A.M. Homes      1       256
# ...                                                 ...    ...       ...
# 6634                         Émile Zola/Henri Mitterand      1       462
# 6635         Émile Zola/Robert Lethbridge/Elinor Dorday      1       592
# 6636                Émile Zola/Robin Buss/Brian  Nelson      1       438
# 6637                           Émile Zola/Roger Pearson      2      1056
# 6638                              Éric-Emmanuel Schmitt      1        85
#
# [6639 rows x 3 columns]

# %%
df3["authors_avg_page"]=(df["num_page"]/df3["title"]).astype('int')
df3
# Out:
#                                                 authors  title  num_page  \
# 0                           A.B. Yehoshua/Hillel Halkin      2       832
# 1          A.D.P. Briggs/Leo Tolstoy/Fyodor Dostoyevsky      1       256
# 2     A.E. Cunningham/Harlan Ellison/Charles F. Mill...      1       232
# 3                                           A.J. Jacobs      1       389
# 4                                            A.M. Homes      1       256
# ...                                                 ...    ...       ...
# 6634                         Émile Zola/Henri Mitterand      1       462
# 6635         Émile Zola/Robert Lethbridge/Elinor Dorday      1       592
# 6636                Émile Zola/Robin Buss/Brian  Nelson      1       438
# 6637                           Émile Zola/Roger Pearson      2      1056
# 6638                              Éric-Emmanuel Schmitt      1        85
#
#       authors_avg_page
# 0                  416
# 1                  256
# ...

# %%
df3.sort_values(by=["authors_avg_page"],ascending =False)
# Out:
#                                                 authors  title  num_page  \
# 6564                   Winston S. Churchill/John Keegan      1      4736
# 3974  Marcel Proust/C.K. Scott Moncrieff/Frederick A...      1      3400
# 1373  Dennis L. Kasper/Dan L. Longo/Stephen L. Hause...      1      2751
# 336                                           Anonymous      1      2198
# 3706  Laurence L. Brunton/John S. Lazo/Keith  L. Parker      1      2021
# ...                                                 ...    ...       ...
# 544                                        Barry Chubin      1         0
# 4133                        Mark Twain/Michael Prichard      1         0
# 3162            John Grisham/Michael Beck/Frank  Muller      1         0
# 3118                        John Banville/John      Lee      1         0
# 3161  John Grisham/Michael Beck/Blair Brown/D.W. Mof...      1         0
#
#       authors_avg_page
# 6564              4736
# 3974              3400
# ...

# %%
plt.scatter(df3["title"],df3["authors_avg_page"])
plt.xlabel("No of books written by author")
plt.ylabel("author average page count")
plt.show()

# %%
# books written less than 200 pages
books_df[books_df["num_page"]<=200].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2949 entries, 5 to 11117
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              2949 non-null   int64
#  1   title               2949 non-null   object
#  2   authors             2949 non-null   object
#  3   average_rating      2949 non-null   float64
#  4   isbn                2949 non-null   object
#  5   isbn13              2949 non-null   int64
#  6   language_code       2949 non-null   object
#  7   num_page            2949 non-null   int64
#  8   ratings_count       2949 non-null   int64
#  9   text_reviews_count  2949 non-null   int64
#  10  publication_date    2949 non-null   object
#  11  publisher           2949 non-null   object
#  12  w_rating            2949 non-null   float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 322.5+ KB

# %%
# Houghton Mifflin Harcourt most popular books
HMH_books = books_df[books_df["publisher"]=="Houghton Mifflin Harcourt"].sort_values(by=["w_rating"],ascending=False)
HMH_books.head(3)
# Out:
#       bookID                                              title  \
# 23        34  The Fellowship of the Ring (The Lord of the Ri...
# 4172   14942                                      Mrs. Dalloway
# 1585    5472                                 Animal Farm / 1984
#
#                                  authors  average_rating        isbn  \
# 23                        J.R.R. Tolkien            4.36  0618346252
# 4172       Virginia Woolf/Maureen Howard            3.79  0151009988
# 1585  George Orwell/Christopher Hitchens            4.28  0151010269
#
#              isbn13 language_code  num_page  ratings_count  \
# 23    9780618346257           eng       398        2128944
# 4172  9780151009985           eng       194         176190
# 1585  9780151010264           eng       400         146659
#
#       text_reviews_count publication_date                  publisher  \
# 23                 13670             2003  Houghton Mifflin Harcourt
# ...

# %%
HMH_books.iloc[0].title
# Out:
# 'The Fellowship of the Ring (The Lord of the Rings  #1)'

# %%
# 5 most popular books by HMH publishers
plt.figure(figsize=(20,8))
plt.bar(HMH_books["title"][:5],height=HMH_books["w_rating"][:5])
plt.xlabel("Books title")
plt.ylabel("popularity Measure")
plt.title('Most 5 popular books by Houghton Mifflin Harcourt publisher')
plt.show()

# %%
df5 =pd.DataFrame(books_df.groupby(by=["authors"],as_index=False)['w_rating'].max())
print(df5.shape)
df5
# Out:
# (6639, 2)
#                                                 authors  w_rating
# 0                           A.B. Yehoshua/Hillel Halkin   2918.93
# 1          A.D.P. Briggs/Leo Tolstoy/Fyodor Dostoyevsky     63.92
# 2     A.E. Cunningham/Harlan Ellison/Charles F. Mill...     53.95
# 3                                           A.J. Jacobs  91153.68
# 4                                            A.M. Homes  10764.96
# ...                                                 ...       ...
# 6634                         Émile Zola/Henri Mitterand  25549.58
# 6635         Émile Zola/Robert Lethbridge/Elinor Dorday   3292.21
# 6636                Émile Zola/Robin Buss/Brian  Nelson  22044.75
# 6637                           Émile Zola/Roger Pearson  95543.42
# 6638                              Éric-Emmanuel Schmitt   3724.50
#
# [6639 rows x 2 columns]

# %%
df5.info()

# %%
# least popular books of 90s 
df6 =books_df[books_df["publication_date"]=="1990"].sort_values(by=["w_rating"])
df6.head(3)
# Out:
#        bookID                                              title  \
# 7287    28052  Dark Intimacy: Hope for Those in Difficult Pra...
# 10212   41404  The Savage Wars Of Peace: Soldiers' Voices 194...
# 6310    23799         The Dark Descent  Vol 1: The Color of Evil
#
#                  authors  average_rating        isbn         isbn13  \
# 7287     David J. Hassel            4.00  0829407081  9780829407082
# 10212      Charles Allen            4.50  0718128826  9780718128821
# 6310   David G. Hartwell            4.12  0246136677  9780246136671
#
#       language_code  num_page  ratings_count  text_reviews_count  \
# 7287            eng       172              1                   0
# 10212           eng       290              1                   0
# 6310            eng       304              2                   0
#
#       publication_date                               publisher  w_rating
# 7287              1990                  Loyola Press (Chicago)      4.00
# ...

# %%
df6.iloc[0].title
# Out:
# 'Dark Intimacy: Hope for Those in Difficult Prayer-Experiences'

# %%
plt.figure(figsize=(30,10))
plt.rcParams['font.size']=10
plt.rcParams['font.weight']='bold'
plt.bar(df6["title"][:5],height=df6["w_rating"][:5])
plt.xlabel("Books title",fontsize=25, color='r')
plt.ylabel("popularity Measure",fontsize=25, color='r')
plt.title('Least 5 popular books of 90s',fontsize=45,color='b')

plt.show()

# %%
# books rated highest which have pages more than 500
df7 =books_df[books_df["num_page"]>=500].sort_values(by=["average_rating"],ascending=False)

# %%
df7.head(2)
# Out:
#       bookID                                              title  \
# 5648   20957  Colossians and Philemon: A Critical and Exeget...
# 6587   24812                     The Complete Calvin and Hobbes
#
#              authors  average_rating        isbn         isbn13 language_code  \
# 5648  R. McL. Wilson            5.00  0567044718  9780567044716           eng
# 6587  Bill Watterson            4.82  0740748475  9780740748479           eng
#
#       num_page  ratings_count  text_reviews_count publication_date  \
# 5648       512              1                   0             2005
# 6587      1456          32213                 930             2005
#
#                       publisher   w_rating
# 5648            T&T Clark Int'l       5.00
# 6587  Andrews McMeel Publishing  155266.66

# %%
plt.scatter(df7["average_rating"],df7["ratings_count"])

# %%
df7.iloc[0].title
# Out:
# 'Colossians and Philemon: A Critical and Exegetical Commentary (International Critical Commentary)'

# %%
corr =books_df.corr()
corr
# Out:
#                       bookID  average_rating    isbn13  num_page  \
# bookID              1.000000       -0.036207 -0.002185 -0.026134
# average_rating     -0.036207        1.000000 -0.001965  0.150477
# isbn13             -0.002185       -0.001965  1.000000 -0.009818
# num_page           -0.026134        0.150477 -0.009818  1.000000
# ratings_count      -0.076820        0.038224  0.005494  0.034337
# text_reviews_count -0.081289        0.033663  0.008152  0.036977
# w_rating           -0.077622        0.044985  0.005294  0.036182
#
#                     ratings_count  text_reviews_count  w_rating
# bookID                  -0.076820           -0.081289 -0.077622
# average_rating           0.038224            0.033663  0.044985
# isbn13                   0.005494            0.008152  0.005294
# num_page                 0.034337            0.036977  0.036182
# ratings_count            1.000000            0.865977  0.997043
# ...

# %%
plt.plot(corr["ratings_count"],corr["w_rating"],color='r')

# %%
plt.plot(corr["w_rating"],corr["average_rating"],color='b')

# %%
plt.plot(corr["text_reviews_count"],corr["ratings_count"],color='y')

# %%
np.std(books_df,axis=0)
# Out:
# C:\Users\RAHUL SUTHAR\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3571: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# bookID                1.309414e+04
# average_rating        3.504696e-01
# isbn13                4.429559e+11
# num_page              2.411418e+02
# ratings_count         1.124941e+05
# text_reviews_count    2.576504e+03
# w_rating              4.532409e+05
# dtype: float64

# %%
books_df.sort_values(by=['average_rating'],ascending=False)
# Out:
#        bookID                                              title  \
# 624      2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 9893    39829  His Princess Devotional: A Royal Encounter Wit...
# 4788    17224  The Diamond Color Meditation: Color Pathway to...
# 9324    36853                 Tyrannosaurus Wrecks (Stanley  #1)
# 9720    38804      The Irish Anatomist: A Study of Flann O'Brien
# ...       ...                                                ...
# 6877    25903  I'll Be Home Before Midnight and I Won't Get P...
# 3492    12712  Brodie's notes on Aldous Huxley's brave new world
# 2533     9338         Insights: Talks On The Nature Of Existence
# 2532     9337  How To Meditate: An Anthology Of Talks On Medi...
# 10497   42758  The Fantastic Vampire: Studies in the Children...
#
#                                                  authors  average_rating  \
# 624                  Aristophanes/F.W. Hall/W.M. Geldart             5.0
# ...

# %%
books_df.iloc[5562]
# Out:
# bookID                                         20315
# title                 The Dark City (Eliot Ness  #1)
# authors                            Max Allan Collins
# average_rating                                  3.88
# isbn                                      0727862421
# isbn13                                 9780727862426
# language_code                                    eng
# num_page                                         233
# ratings_count                                     49
# text_reviews_count                                 5
# publication_date                                2005
# publisher                    Severn House Publishers
# w_rating                                      190.12
# Name: 5562, dtype: object

# %%
11123/2
# Out:
# 5561.5

# %%
books_df[books_df["authors"]=='Stephen King'].count()

# %% [markdown]
# We have given a books dataset. Dataset contains the following columns
# * ['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#    'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#     'publication_date', 'publisher']
# * Data type of columns is int,object or float type.Dataset not contains any nulll value
#   but their are one bad lines which we have to skip .
# * Shape of Dataset is (11123,12) means their total 11123 rows and 12 columns.
#   their also some outliers like some books with 0 average rating because rating count is also
#   0. also 1 row which have 5 rating but rating count is 0 . and some rows with 5 rating with -12 rating counts
#   which is outliers .
# * The size of dataset is 133476.
# * To measure popularity of books we can't use only average rating or only rating count
#   so we use multiple of average rating and rating count. using this we got Most Popular books as " Twilight (Twilight #1)" by     "Stephenie Meyer" with  average rating of 3.59
# *  Book publish by Little Brown and Company in 9 June 2006.
# *  Books which are more pages rated mostly higher.
# *  In 60s only 6 books were published and most popular books of 60s is "Paws Before Dying (A Dog Lover's Mystery #4)" written     by "Susan Conant" and publish by "Berkley Books".
# *  The author "Stephen King " wrote most page. 18219 pages is written by Stephen King
#    He writes  40 books .
# *  2949 books that are written in less or equal 200 pages.
# *  Most popular books which are publish by Houghton Mifflin Harcourt is
#    "The Fellowship of the Ring (The Lord of the Rings #1)" written by J.R.R. Tolkien
#    and publish in 2003.
# * "Dark Intimacy: Hope for Those in Difficult Prayer-Experiences" is least popular book of 90s.
# * "Colossians and Philemon: A Critical and Exegetical Commentary (International Critical Commentary)"
#    is highest rated books which have more than 500 pages written by "R. McL. Wilson" but consider the fact that rating count is     only 1.

# %%
books_df["num_page"] = books_df["num_page"].astype('int')
