# %%
import pandas as pd
import numpy as np

# %%
movie_df = pd.read_csv(r'IMDB-Movie-Data.csv',index_col=1)
movie_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# ## Data cleaning

# %%
movie_df.head(10)
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
movie_df.tail(5)
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
movie_df.shape
# Out:
# (1000, 11)

# %%
new_df = movie_df.append(movie_df)
# Out:
# C:\Users\RAHUL SUTHAR\AppData\Local\Temp\ipykernel_9040\2015483576.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = movie_df.append(movie_df)

# %%
new_df.shape
# Out:
# (2000, 11)

# %% [markdown]
# ## deal with duplicates

# %%
new_df.drop_duplicates().shape
# Out:
# (1000, 11)

# %%
movie_df.drop_duplicates().shape
# Out:
# (1000, 11)

# %%
new_df.shape
# Out:
# (2000, 11)

# %%
new_df.drop_duplicates(inplace=True)

# %%
new_df.shape
# Out:
# (1000, 11)

# %%
new_df = movie_df.append(movie_df)
# Out:
# C:\Users\RAHUL SUTHAR\AppData\Local\Temp\ipykernel_9040\2015483576.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = movie_df.append(movie_df)

# %%
# keep first value between duplicates and delete second occurence
# keep==false then delete all duplicates value 
new_df.drop_duplicates(inplace=True,keep='first')

# %%
new_df.shape
# Out:
# (1000, 11)

# %%
movie_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# deal with columns name inconsistency
movie_df.columns =['rank','genre','description','director','actors','year','runtime','rating','votes','revenue','metascore']

# %%
movie_df.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue', 'metascore'],
#       dtype='object')

# %%
new_df.columns = [col.lower() for col in new_df]

# %%
new_df.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime (minutes)', 'rating', 'votes', 'revenue (millions)',
#        'metascore'],
#       dtype='object')

# %% [markdown]
# ###  Replace Missing value

# %%
movie_df.describe()
# Out:
#               rank         year      runtime       rating         votes  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000   113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962    18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000    66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000   100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000   111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000   123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000   191.000000     9.000000  1.791916e+06
#
#           revenue   metascore
# count  872.000000  936.000000
# mean    82.956376   58.985043
# std    103.253540   17.194757
# min      0.000000   11.000000
# 25%     13.270000   47.000000
# 50%     47.985000   59.500000
# 75%    113.715000   72.000000
# max    936.630000  100.000000

# %%
movie_df['revenue'].isnull()
# Out:
# Title
# Guardians of the Galaxy    False
# Prometheus                 False
# Split                      False
# Sing                       False
# Suicide Squad              False
#                            ...
# Secret in Their Eyes        True
# Hostel: Part II            False
# Step Up 2: The Streets     False
# Search Party                True
# Nine Lives                 False
# Name: revenue, Length: 1000, dtype: bool

# %%
movie_df.drop(columns=['description'] ,axis=1)
# Out:
#                          rank                     genre              director  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi            James Gunn
# Prometheus                  2  Adventure,Mystery,Sci-Fi          Ridley Scott
# Split                       3           Horror,Thriller    M. Night Shyamalan
# Sing                        4   Animation,Comedy,Family  Christophe Lourdelet
# Suicide Squad               5  Action,Adventure,Fantasy            David Ayer
# ...                       ...                       ...                   ...
# Secret in Their Eyes      996       Crime,Drama,Mystery             Billy Ray
# Hostel: Part II           997                    Horror              Eli Roth
# Step Up 2: The Streets    998       Drama,Music,Romance            Jon M. Chu
# Search Party              999          Adventure,Comedy        Scot Armstrong
# Nine Lives               1000     Comedy,Family,Fantasy      Barry Sonnenfeld
#
# ...

# %%
movie_df.shape
# Out:
# (1000, 11)

# %%
rev_med =movie_df['revenue'].median()
ms_med = movie_df['metascore'].median()

print(rev_med,ms_med)
# Out:
# 47.985 59.5

# %%
movie_df['revenue'].fillna(rev_med,inplace=True)
movie_df['metascore'].fillna(ms_med,inplace=True)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         1000 non-null   int64
#  1   genre        1000 non-null   object
#  2   description  1000 non-null   object
#  3   director     1000 non-null   object
#  4   actors       1000 non-null   object
#  5   year         1000 non-null   int64
#  6   runtime      1000 non-null   int64
#  7   rating       1000 non-null   float64
#  8   votes        1000 non-null   int64
#  9   revenue      1000 non-null   float64
#  10  metascore    1000 non-null   float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 126.0+ KB

# %%
movie_df.loc['Guardians of the Galaxy']['revenue']
# Out:
# 333.13

# %%
movie_df[['runtime','revenue']].describe()
# Out:
#            runtime      revenue
# count  1000.000000  1000.000000
# mean    113.172000    78.480040
# std      18.810908    97.118097
# min      66.000000     0.000000
# 25%     100.000000    17.442500
# 50%     111.000000    47.985000
# 75%     123.000000    99.177500
# max     191.000000   936.630000

# %%
movie_df['genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: genre, dtype: object

# %%
movie_df['runtime'].mode()
# Out:
# 0    108
# Name: runtime, dtype: int64

# %%
movie_df['genre'].mode()
# Out:
# 0    Action,Adventure,Sci-Fi
# Name: genre, dtype: object

# %%
movie_df["revenue"].mode()
# Out:
# 0    47.985
# Name: revenue, dtype: float64

# %%
movie_df['genre'].value_counts()
# Out:
# Action,Adventure,Sci-Fi    50
# Drama                      48
# Comedy,Drama,Romance       35
# Comedy                     32
# Drama,Romance              31
#                            ..
# Action,Comedy,Family        1
# Action,Crime,Fantasy        1
# Comedy,Mystery              1
# Adventure,Comedy,Horror     1
# Comedy,Family,Fantasy       1
# Name: genre, Length: 207, dtype: int64

# %%
# correlation
movie_df.corr()
# Out:
#                rank      year   runtime    rating     votes   revenue  \
# rank       1.000000 -0.261605 -0.221739 -0.219555 -0.283876 -0.259607
# year      -0.261605  1.000000 -0.164900 -0.211219 -0.411904 -0.146589
# runtime   -0.221739 -0.164900  1.000000  0.392214  0.407062  0.272955
# rating    -0.219555 -0.211219  0.392214  1.000000  0.511537  0.218448
# votes     -0.283876 -0.411904  0.407062  0.511537  1.000000  0.638758
# revenue   -0.259607 -0.146589  0.272955  0.218448  0.638758  1.000000
# metascore -0.184922 -0.075970  0.202079  0.604522  0.317268  0.141381
#
#            metascore
# rank       -0.184922
# year       -0.075970
# runtime     0.202079
# rating      0.604522
# votes       0.317268
# revenue     0.141381
# metascore   1.000000

# %%
movie_df.head(2)
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          year  runtime  rating   votes  revenue  metascore
# Title
# Guardians of the Galaxy  2014      121     8.1  757074   333.13       76.0
# ...

# %% [markdown]
# ## DataFrame slicing

# %%
sub = movie_df[['director','runtime','revenue']]

# %%
sub
# Out:
#                                      director  runtime  revenue
# Title
# Guardians of the Galaxy            James Gunn      121  333.130
# Prometheus                       Ridley Scott      124  126.460
# Split                      M. Night Shyamalan      117  138.120
# Sing                     Christophe Lourdelet      108  270.320
# Suicide Squad                      David Ayer      123  325.020
# ...                                       ...      ...      ...
# Secret in Their Eyes                Billy Ray      111   47.985
# Hostel: Part II                      Eli Roth       94   17.540
# Step Up 2: The Streets             Jon M. Chu       98   58.010
# Search Party                   Scot Armstrong       93   47.985
# Nine Lives                   Barry Sonnenfeld       87   19.640
#
# [1000 rows x 3 columns]

# %%
rw =sub.loc["Split"]
rw
# Out:
# director    M. Night Shyamalan
# runtime                    117
# revenue                 138.12
# Name: Split, dtype: object

# %%
rw_i = sub.iloc[10]
rw_i
# Out:
# director    David Yates
# runtime             133
# revenue          234.02
# Name: Fantastic Beasts and Where to Find Them, dtype: object

# %%
filtered_data = movie_df[sub['director']=='David Ayer']
filtered_data
# Out:
#                rank                     genre  \
# Title
# Suicide Squad     5  Action,Adventure,Fantasy
# Fury            241          Action,Drama,War
# End of Watch    958      Crime,Drama,Thriller
#
#                                                      description    director  \
# Title
# Suicide Squad  A secret government agency recruits some of th...  David Ayer
# Fury           A grizzled tank commander makes tough decision...  David Ayer
# End of Watch   Shot documentary-style, this film follows the ...  David Ayer
#
#                                                           actors  year  \
# Title
# Suicide Squad  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# Fury           Brad Pitt, Shia LaBeouf, Logan Lerman, Michael...  2014
# End of Watch   Jake Gyllenhaal, Michael Peña, Anna Kendrick, ...  2012
#
#                runtime  rating   votes  revenue  metascore
# Title
# Suicide Squad      123     6.2  393727   325.02       40.0
# ...

# %%
rating = movie_df[movie_df['rating'] >=8.5]
rating
# Out:
#                        rank                    genre  \
# Title
# Interstellar             37   Adventure,Drama,Sci-Fi
# The Dark Knight          55       Action,Crime,Drama
# The Prestige             65     Drama,Mystery,Sci-Fi
# Inception                81  Action,Adventure,Sci-Fi
# Kimi no na wa            97  Animation,Drama,Fantasy
# The Departed            100     Crime,Drama,Thriller
# Dangal                  118   Action,Biography,Drama
# The Dark Knight Rises   125          Action,Thriller
# Whiplash                134              Drama,Music
# The Intouchables        250   Biography,Comedy,Drama
# The Lives of Others     477           Drama,Thriller
# Taare Zameen Par        992       Drama,Family,Music
#
#                                                              description  \
# Title
# Interstellar           A team of explorers travel through a wormhole ...
# The Dark Knight        When the menace known as the Joker wreaks havo...
# ...

# %%
movie_df[(movie_df['rating'] >=7) &  (movie_df['director']=="Christopher Nolan")]
# Out:
#                        rank                    genre  \
# Title
# Interstellar             37   Adventure,Drama,Sci-Fi
# The Dark Knight          55       Action,Crime,Drama
# The Prestige             65     Drama,Mystery,Sci-Fi
# Inception                81  Action,Adventure,Sci-Fi
# The Dark Knight Rises   125          Action,Thriller
#
#                                                              description  \
# Title
# Interstellar           A team of explorers travel through a wormhole ...
# The Dark Knight        When the menace known as the Joker wreaks havo...
# The Prestige           Two stage magicians engage in competitive one-...
# Inception              A thief, who steals corporate secrets through ...
# The Dark Knight Rises  Eight years after the Joker's reign of anarchy...
#
#                                 director  \
# Title
# Interstellar           Christopher Nolan
# The Dark Knight        Christopher Nolan
# The Prestige           Christopher Nolan
# ...
